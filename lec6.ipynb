# %%
print("Bye")
a=5
b=10
print(a>b)
# Out:
# Bye
# False

# %% [markdown]
# # Basic Python

# %%
#Python is interpreted Language
#Interpreted Language are slower
#Python is platfrom independent
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Programming Fundamentals -1 : Intro to Python

# %%
p=100.15
r=5
t=2
si=(p*r*t)/100
print("Simple Interest: ",si)
# Out:
# Simple Interest:  10.015

# %%
name=input()
print("hello",name)
# Out:
# hello manoj

# %%
print("Good evening")
# This is a good evening statement
print("Hello to everyone")
# this is also a print statement
# Out:
# Good evening
# Hello to everyone

# %%
a=100
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# Variable 'a' is storing integer type of data

# %%
b=10.74982374
print(type(b))
# Out:
# <class 'float'>

# %% [markdown]
# Float - Numbers having the decimal point

# %%
c="Hello world"
print(type(c))
# Out:
# <class 'str'>

# %% [markdown]
# str-string

# %%
d=True
print(type(d))
# Out:
# <class 'bool'>

# %%
e=None
# None denoted NULL value
print(type(e))
# Out:
# <class 'NoneType'>

# %%
# variable name must always begin with a character
# variable names are case sensitive
# special characters are not allowed in naming variables (underscore is an exception)
name1
name-1  # Not allowed
nmae_2 # this is allowed

# %%
_name=10
print(_name)
# Out:
# 10

# %% [markdown]
# # Typecasting

# %%
f=7.4

# %% [markdown]
# Convert this float number to an integer

# %% [markdown]
# 7.4 ->7

# %%
f=7.4
i=int(f)
i1=int(-5.3)
i2=int(10.9)
print(i,i1,i2)
# Out:
# 7 -5 10

# %%
a='537'
i=int(a)
print(i,type(i))

i2=int("abcd") # that will give error
# Out:
# 537 <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 5
#       2 i=int(a)
#       3 print(i,type(i))
# ----> 5 i2=int("abcd")
#
# ValueError: invalid literal for int() with base 10: 'abcd'

# %%
#Int to string
x=756565
s=str(x)
print(s,type(s))
# Out:
# 756565 <class 'str'>

# %%
# Convert float to str
s2=str(8.562)
s2
# Out:
# '8.562'

# %%
a=int(float("1.2"))  # for this first we have to convert it into float because it was not valid int string
a
# Out:
# 1

# %% [markdown]
# # Range of Numbers

# %% [markdown]
# Python doesn't have any range of its numbers

# %% [markdown]
# # Operators

# %%
a=5+2 # Addition Operator
a=5-2 # Subtraction
a=5*2 # Multiplication
a=5/2 # Division
a=5//2 #Division.... but return in floor value
print(a)
a=5%2 #Modulo Operator
a=5**2  # Power operator
a
# Out:
# 2
# 25

# %%
x=10**(1/2)  #square root
print(x,type(x))
# Out:
# 3.1622776601683795 <class 'float'>

# %% [markdown]
# # WTF Python github repo by satvik Bansal
# https://github.com/satwikkansal/wtfpython
