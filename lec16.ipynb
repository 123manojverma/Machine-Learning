# %% [markdown]
# # OOPS
# ![image.png](attachment:image.png)

# %%
class Car:
    name="Buggati Chiron"
    color="Red"
    age=2
    def describe(self):
        print("This is a car function. Describe cars here")
benz=Car()
benz

# %%
benz.name
# Out:
# 'Buggati Chiron'

# %%
benz.name="Mercedes"
benz.color="Silver"
benz.age=3
benz.fuel="Petrol"
print(benz.name,benz.age,benz.color,benz.fuel)
benz.describe()
# Out:
# Mercedes 3 Silver Petrol
# This is a car function. Describe cars here
# 1

# %% [markdown]
# ## Create Class Without Passing Anything

# %%
class Car1:
    pass
maruti=Car1()
maruti

# %%
class Car:
    def describe(self):
        print("Car name: ",self.name)
        print("Car color: ",self.color)
        print("Car age: ",self.age)
    def isBanned(self):
        return self.age>15

# %%
benz=Car()
benz.name="Mercedes"
benz.color="Silver"
benz.age=2
benz.describe()
benz.isBanned()
# Out:
# Car name:  Mercedes
# Car color:  Silver
# Car age:  2
# False

# %% [markdown]
# ## Constructors

# %%
class Car:
    def __init__(self,name,color,age):
        self.name=name
        self.color=color
        self.age=age
        
    def describe(self):
        print("Car name: ",self.name)
        print("Car color: ",self.color)
        print("Car age: ",self.age)

# %%
mac=Car("P1","Orange","Maclaren")
mac.describe()
# Out:
# Car name:  P1
# Car color:  Orange
# Car age:  Maclaren

# %% [markdown]
# ## Nested Classes

# %%
class Car:
    class Seat:
        def __init__(self,color="grey"):
            self.color=color
    def __init__(self):
        self.name="Lamborghini"
    def drive(self):
        s=self.Seat("Red")
        print(s)
        print(s.color)
c=Car()
c.drive()
# Out:
# <__main__.Car.Seat object at 0x00000277ACB8E7B0>
# Red
